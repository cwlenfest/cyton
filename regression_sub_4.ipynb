# %%
from sklearn import preprocessing
from sklearn import model_selection
import statistics as stat
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense


mse=np.zeros(50)

for i in range(50):
    model = Sequential()
    dataset = pd.read_csv("Concrete_Data.csv")
    dataset = preprocessing.normalize(dataset)
    
    training_data, test_data = model_selection.train_test_split(dataset, test_size=0.3)
    
    x_train = training_data[:, 0:8]
    x_test = test_data[:, 0:8]
    y_train = training_data[:, 8]
    y_test = test_data[:, 8] 
    n_cols = training_data.shape[1]
    
    model.add(Dense(10,activation='relu',input_shape=(n_cols-1,)))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(x_train, y_train, epochs=100);

    y_predict = model.predict(x_test)

    mse[i]=sklearn.metrics.mean_squared_error(y_test,y_predict)

mean_mse=stat.mean(mse) #Find the mean of the mean squared error
sd_mse=stat.stdev(mse) #Find the standard deviation of the mean squared error
print("Mean",mean_mse)
print("SD",sd_mse)
# Out:
# Epoch 1/100
# 721/721 [==============================] - 1s 763us/step - loss: 2.9738e-04
# Epoch 2/100
# 721/721 [==============================] - 0s 75us/step - loss: 1.4212e-04
# Epoch 3/100
# 721/721 [==============================] - 0s 71us/step - loss: 1.0537e-04
# Epoch 4/100
# 721/721 [==============================] - 0s 75us/step - loss: 9.4356e-05
# Epoch 5/100
# 721/721 [==============================] - 0s 69us/step - loss: 9.6449e-05
# Epoch 6/100
# 721/721 [==============================] - 0s 69us/step - loss: 8.5923e-05
# Epoch 7/100
# 721/721 [==============================] - 0s 78us/step - loss: 8.0566e-05
# Epoch 8/100
# 721/721 [==============================] - 0s 75us/step - loss: 8.1214e-05
# Epoch 9/100
# 721/721 [==============================] - 0s 78us/step - loss: 7.6700e-05
# Epoch 10/100
# 721/721 [==============================] - 0s 76us/step - loss: 7.1865e-05
# Epoch 11/100
# ...
